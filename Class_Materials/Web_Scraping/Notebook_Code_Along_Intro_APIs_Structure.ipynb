# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '19030697896',
#   'type': 'PushEvent',
#   'actor': {'id': 15614155,
#    'login': 'IgorBaratta',
#    'display_login': 'IgorBaratta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IgorBaratta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15614155?'},
#   'repo': {'id': 128215037,
#    'name': 'FEniCS/ffcx',
#    'url': 'https://api.github.com/repos/FEniCS/ffcx'},
#   'payload': {'push_id': 8461343794,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/igor/unit-stride-tensor',
#    'head': '30e57d757a82c0d9b6c45eae2a988cf06ac4fc61',
#    'before': '256d8620fa084c0703346f176f32e82ce63995be',
#    'commits': [{'sha': '30e57d757a82c0d9b6c45eae2a988cf06ac4fc61',
#      'author': {'email': 'igorbaratta@gmail.com', 'name': 'IgorBaratta'},
#      'message': 'remove print',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FEniCS/ffcx/commits/30e57d757a82c0d9b6c45eae2a988cf06ac4fc61'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z',
#   'org': {'id': 3868708,
#    'login': 'FEniCS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FEniCS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3868708?'}},
#  {'id': '19030697911',
#   'type': 'PushEvent',
#   'actor': {'id': 69833978,
#    'login': 'mohmohaye707',
#    'display_login': 'mohmohaye707',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mohmohaye707',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69833978?'},
#   'repo': {'id': 430998830,
#    'name': 'mohmohaye707/Crud_reactapp',
#    'url': 'https://api.github.com/repos/mohmohaye707/Crud_reactapp'},
#   'payload': {'push_id': 8461343824,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '85529a0170fc868aa6caefce0c1f73ed6bc9e691',
#    'before': 'ebe8284d080eb793f7999176a377ee62546f3e46',
#    'commits': [{'sha': '85529a0170fc868aa6caefce0c1f73ed6bc9e691',
#      'author': {'email': 'mohmohaye707@gmail.com', 'name': 'Ma Moh Moh Aye'},
#      'message': 'fourth commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mohmohaye707/Crud_reactapp/commits/85529a0170fc868aa6caefce0c1f73ed6bc9e691'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697927',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 147852516,
#    'name': 'nwtgck/fakelish-npm',
#    'url': 'https://api.github.com/repos/nwtgck/fakelish-npm'},
#   'payload': {'action': 'opened',
#    'number': 106,
#    'pull_request': {'url': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/106',
#     'id': 787793228,
#     'node_id': 'PR_kwDOCNAM5M4u9MVM',
#     'html_url': 'https://github.com/nwtgck/fakelish-npm/pull/106',
#     'diff_url': 'https://github.com/nwtgck/fakelish-npm/pull/106.diff',
#     'patch_url': 'https://github.com/nwtgck/fakelish-npm/pull/106.patch',
#     'issue_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/106',
#     'number': 106,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump @types/node from 10.17.60 to 16.11.10',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@types/node](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/node) from 10.17.60 to 16.11.10.\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/DefinitelyTyped/DefinitelyTyped/commits/HEAD/types/node">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@types/node&package-manager=npm_and_yarn&previous-version=10.17.60&new-version=16.11.10)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>',
#     'created_at': '2021-11-24T10:21:27Z',
#     'updated_at': '2021-11-24T10:21:27Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/106/commits',
#     'review_comments_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/106/comments',
#     'review_comment_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/106/comments',
#     'statuses_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/statuses/29f3b7332e68272c33b53d57c4a34043c2f7b65a',
#     'head': {'label': 'nwtgck:dependabot/npm_and_yarn/types/node-16.11.10',
#      'ref': 'dependabot/npm_and_yarn/types/node-16.11.10',
#      'sha': '29f3b7332e68272c33b53d57c4a34043c2f7b65a',
#      'user': {'login': 'nwtgck',
#       'id': 10933561,
#       'node_id': 'MDQ6VXNlcjEwOTMzNTYx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/10933561?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nwtgck',
#       'html_url': 'https://github.com/nwtgck',
#       'followers_url': 'https://api.github.com/users/nwtgck/followers',
#       'following_url': 'https://api.github.com/users/nwtgck/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nwtgck/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nwtgck/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nwtgck/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nwtgck/orgs',
#       'repos_url': 'https://api.github.com/users/nwtgck/repos',
#       'events_url': 'https://api.github.com/users/nwtgck/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nwtgck/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 147852516,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNDc4NTI1MTY=',
#       'name': 'fakelish-npm',
#       'full_name': 'nwtgck/fakelish-npm',
#       'private': False,
#       'owner': {'login': 'nwtgck',
#        'id': 10933561,
#        'node_id': 'MDQ6VXNlcjEwOTMzNTYx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/10933561?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/nwtgck',
#        'html_url': 'https://github.com/nwtgck',
#        'followers_url': 'https://api.github.com/users/nwtgck/followers',
#        'following_url': 'https://api.github.com/users/nwtgck/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/nwtgck/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/nwtgck/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/nwtgck/subscriptions',
#        'organizations_url': 'https://api.github.com/users/nwtgck/orgs',
#        'repos_url': 'https://api.github.com/users/nwtgck/repos',
#        'events_url': 'https://api.github.com/users/nwtgck/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/nwtgck/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/nwtgck/fakelish-npm',
#       'description': ' Fake English word generator for JavaScript/TypeScript',
#       'fork': False,
#       'url': 'https://api.github.com/repos/nwtgck/fakelish-npm',
#       'forks_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/forks',
#       'keys_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/teams',
#       'hooks_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/hooks',
#       'issue_events_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/events',
#       'assignees_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/tags',
#       'blobs_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/languages',
#       'stargazers_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/stargazers',
#       'contributors_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/contributors',
#       'subscribers_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/subscribers',
#       'subscription_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/subscription',
#       'commits_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/merges',
#       'archive_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/downloads',
#       'issues_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/deployments',
#       'created_at': '2018-09-07T17:05:47Z',
#       'updated_at': '2021-08-29T11:09:42Z',
#       'pushed_at': '2021-11-24T10:21:26Z',
#       'git_url': 'git://github.com/nwtgck/fakelish-npm.git',
#       'ssh_url': 'git@github.com:nwtgck/fakelish-npm.git',
#       'clone_url': 'https://github.com/nwtgck/fakelish-npm.git',
#       'svn_url': 'https://github.com/nwtgck/fakelish-npm',
#       'homepage': '',
#       'size': 4407,
#       'stargazers_count': 42,
#       'watchers_count': 42,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['english',
#        'english-like',
#        'fake',
#        'generator',
#        'nodejs',
#        'npm',
#        'word'],
#       'visibility': 'public',
#       'forks': 3,
#       'open_issues': 7,
#       'watchers': 42,
#       'default_branch': 'develop'}},
#     'base': {'label': 'nwtgck:develop',
#      'ref': 'develop',
#      'sha': '91350669040bafb2397bacbd3088abdfff9e6158',
#      'user': {'login': 'nwtgck',
#       'id': 10933561,
#       'node_id': 'MDQ6VXNlcjEwOTMzNTYx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/10933561?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nwtgck',
#       'html_url': 'https://github.com/nwtgck',
#       'followers_url': 'https://api.github.com/users/nwtgck/followers',
#       'following_url': 'https://api.github.com/users/nwtgck/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nwtgck/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nwtgck/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nwtgck/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nwtgck/orgs',
#       'repos_url': 'https://api.github.com/users/nwtgck/repos',
#       'events_url': 'https://api.github.com/users/nwtgck/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nwtgck/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 147852516,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNDc4NTI1MTY=',
#       'name': 'fakelish-npm',
#       'full_name': 'nwtgck/fakelish-npm',
#       'private': False,
#       'owner': {'login': 'nwtgck',
#        'id': 10933561,
#        'node_id': 'MDQ6VXNlcjEwOTMzNTYx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/10933561?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/nwtgck',
#        'html_url': 'https://github.com/nwtgck',
#        'followers_url': 'https://api.github.com/users/nwtgck/followers',
#        'following_url': 'https://api.github.com/users/nwtgck/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/nwtgck/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/nwtgck/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/nwtgck/subscriptions',
#        'organizations_url': 'https://api.github.com/users/nwtgck/orgs',
#        'repos_url': 'https://api.github.com/users/nwtgck/repos',
#        'events_url': 'https://api.github.com/users/nwtgck/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/nwtgck/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/nwtgck/fakelish-npm',
#       'description': ' Fake English word generator for JavaScript/TypeScript',
#       'fork': False,
#       'url': 'https://api.github.com/repos/nwtgck/fakelish-npm',
#       'forks_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/forks',
#       'keys_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/teams',
#       'hooks_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/hooks',
#       'issue_events_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/events',
#       'assignees_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/tags',
#       'blobs_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/languages',
#       'stargazers_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/stargazers',
#       'contributors_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/contributors',
#       'subscribers_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/subscribers',
#       'subscription_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/subscription',
#       'commits_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/merges',
#       'archive_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/downloads',
#       'issues_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/nwtgck/fakelish-npm/deployments',
#       'created_at': '2018-09-07T17:05:47Z',
#       'updated_at': '2021-08-29T11:09:42Z',
#       'pushed_at': '2021-11-24T10:21:26Z',
#       'git_url': 'git://github.com/nwtgck/fakelish-npm.git',
#       'ssh_url': 'git@github.com:nwtgck/fakelish-npm.git',
#       'clone_url': 'https://github.com/nwtgck/fakelish-npm.git',
#       'svn_url': 'https://github.com/nwtgck/fakelish-npm',
#       'homepage': '',
#       'size': 4407,
#       'stargazers_count': 42,
#       'watchers_count': 42,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['english',
#        'english-like',
#        'fake',
#        'generator',
#        'nodejs',
#        'npm',
#        'word'],
#       'visibility': 'public',
#       'forks': 3,
#       'open_issues': 7,
#       'watchers': 42,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/106'},
#      'html': {'href': 'https://github.com/nwtgck/fakelish-npm/pull/106'},
#      'issue': {'href': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/106'},
#      'comments': {'href': 'https://api.github.com/repos/nwtgck/fakelish-npm/issues/106/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/106/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/nwtgck/fakelish-npm/pulls/106/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/nwtgck/fakelish-npm/statuses/29f3b7332e68272c33b53d57c4a34043c2f7b65a'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697917',
#   'type': 'PushEvent',
#   'actor': {'id': 13050025,
#    'login': 'aladdin-add',
#    'display_login': 'aladdin-add',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aladdin-add',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13050025?'},
#   'repo': {'id': 416723766,
#    'name': 'weiran-zsd/talks',
#    'url': 'https://api.github.com/repos/weiran-zsd/talks'},
#   'payload': {'push_id': 8461343812,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '44c586e7a59ea954b28b2342f7727322eacf6276',
#    'before': '574f2156e159ae57fc7f51c69e3973ef5d04eda1',
#    'commits': [{'sha': '44c586e7a59ea954b28b2342f7727322eacf6276',
#      'author': {'email': 'weiran.zsd@outlook.com', 'name': '唯然'},
#      'message': 'docs: add esm talk',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/weiran-zsd/talks/commits/44c586e7a59ea954b28b2342f7727322eacf6276'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z',
#   'org': {'id': 74645970,
#    'login': 'weiran-zsd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/weiran-zsd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74645970?'}},
#  {'id': '19030697915',
#   'type': 'PushEvent',
#   'actor': {'id': 84066249,
#    'login': 'jaeseonNamgung',
#    'display_login': 'jaeseonNamgung',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jaeseonNamgung',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84066249?'},
#   'repo': {'id': 398953505,
#    'name': 'jaeseonNamgung/Study_Note',
#    'url': 'https://api.github.com/repos/jaeseonNamgung/Study_Note'},
#   'payload': {'push_id': 8461343818,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd56f3afa890dec5ee70d56af47b7f820ecb5127c',
#    'before': '948db81e01d057727c4e17d32a6d0e67fd45efa0',
#    'commits': [{'sha': 'd56f3afa890dec5ee70d56af47b7f820ecb5127c',
#      'author': {'email': 'sunnamgung8@naver.com', 'name': 'jaeseonNamgung'},
#      'message': '내장객체 정의',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jaeseonNamgung/Study_Note/commits/d56f3afa890dec5ee70d56af47b7f820ecb5127c'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697887',
#   'type': 'PushEvent',
#   'actor': {'id': 693300,
#    'login': 'labeneko',
#    'display_login': 'labeneko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/labeneko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/693300?'},
#   'repo': {'id': 418538630,
#    'name': 'labeneko/keihin00788',
#    'url': 'https://api.github.com/repos/labeneko/keihin00788'},
#   'payload': {'push_id': 8461343804,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'eb18daa8febad0de97714345f902a7988d4600a8',
#    'before': 'be6a74dc3c1021acf43b7ff88ee9ef1f342afcad',
#    'commits': [{'sha': 'eb18daa8febad0de97714345f902a7988d4600a8',
#      'author': {'email': 'info@laboneko.jp', 'name': 'labeneko'},
#      'message': 'Update from https://github.com/labeneko/time/commit/99a09cec56192d7ba3f721a84c2230528f3d093a',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/labeneko/keihin00788/commits/eb18daa8febad0de97714345f902a7988d4600a8'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697932',
#   'type': 'WatchEvent',
#   'actor': {'id': 16855333,
#    'login': 'pedrorlmarques',
#    'display_login': 'pedrorlmarques',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pedrorlmarques',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855333?'},
#   'repo': {'id': 352759446,
#    'name': 'vinsguru/rsocket-course',
#    'url': 'https://api.github.com/repos/vinsguru/rsocket-course'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697919',
#   'type': 'PushEvent',
#   'actor': {'id': 92030018,
#    'login': 'v-rpatkur',
#    'display_login': 'v-rpatkur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/v-rpatkur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92030018?'},
#   'repo': {'id': 378043407,
#    'name': 'zyxiaoyuer/msteams-docs',
#    'url': 'https://api.github.com/repos/zyxiaoyuer/msteams-docs'},
#   'payload': {'push_id': 8461343789,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/zyxiaoyuer-Teams-Toolkie-User-Manual',
#    'head': '6d4ee88fde9eece7f15a589d4b0a481f28bcb8de',
#    'before': '2aaa173f66da9c139e81caa6d2c2e3113dad8a8e',
#    'commits': [{'sha': '6d4ee88fde9eece7f15a589d4b0a481f28bcb8de',
#      'author': {'email': 'v-rpatkur@microsoft.com', 'name': 'v-rpatkur'},
#      'message': 'Update TeamsFx-multi-env.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zyxiaoyuer/msteams-docs/commits/6d4ee88fde9eece7f15a589d4b0a481f28bcb8de'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697934',
#   'type': 'CreateEvent',
#   'actor': {'id': 89453364,
#    'login': 'ViktorTB',
#    'display_login': 'ViktorTB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ViktorTB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89453364?'},
#   'repo': {'id': 426579718,
#    'name': 'ViktorTB/Mini-eksamen',
#    'url': 'https://api.github.com/repos/ViktorTB/Mini-eksamen'},
#   'payload': {'ref': 'Lærer',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Mini eksamensprojekt til DDU i skolen HTX Lyngby 3a2 2021',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697907',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 147852516,
#    'name': 'nwtgck/fakelish-npm',
#    'url': 'https://api.github.com/repos/nwtgck/fakelish-npm'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/types/node-16.11.10',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': ' Fake English word generator for JavaScript/TypeScript',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697933',
#   'type': 'CreateEvent',
#   'actor': {'id': 61286605,
#    'login': 'AlexShkreba',
#    'display_login': 'AlexShkreba',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AlexShkreba',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61286605?'},
#   'repo': {'id': 426592187,
#    'name': 'AlexShkreba/mobile-api',
#    'url': 'https://api.github.com/repos/AlexShkreba/mobile-api'},
#   'payload': {'ref': 'tests',
#    'ref_type': 'branch',
#    'master_branch': 'origin',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697906',
#   'type': 'PushEvent',
#   'actor': {'id': 94030960,
#    'login': 'banifahlevi',
#    'display_login': 'banifahlevi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/banifahlevi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94030960?'},
#   'repo': {'id': 431019726,
#    'name': 'banifahlevi/banifahlevi.github.io',
#    'url': 'https://api.github.com/repos/banifahlevi/banifahlevi.github.io'},
#   'payload': {'push_id': 8461343827,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd1e40393f5dc263528fb4530c1c3663bb3042ffd',
#    'before': '6591bd9973e2f61c11d6c2853f571984152bf670',
#    'commits': [{'sha': 'd1e40393f5dc263528fb4530c1c3663bb3042ffd',
#      'author': {'email': '94030960+banifahlevi@users.noreply.github.com',
#       'name': 'Bani Fahlevi'},
#      'message': 'Delete Monitoring Target.PNG',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/banifahlevi/banifahlevi.github.io/commits/d1e40393f5dc263528fb4530c1c3663bb3042ffd'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697886',
#   'type': 'WatchEvent',
#   'actor': {'id': 76036471,
#    'login': 'ffit8',
#    'display_login': 'ffit8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ffit8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76036471?'},
#   'repo': {'id': 405838857,
#    'name': 'qishanzhiruan/basemall',
#    'url': 'https://api.github.com/repos/qishanzhiruan/basemall'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697893',
#   'type': 'PushEvent',
#   'actor': {'id': 41169759,
#    'login': 'shaurya-src',
#    'display_login': 'shaurya-src',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaurya-src',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41169759?'},
#   'repo': {'id': 414986829,
#    'name': 'shaurya-src/CovidInsight',
#    'url': 'https://api.github.com/repos/shaurya-src/CovidInsight'},
#   'payload': {'push_id': 8461343793,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c32e587995def8b6b12489983bdd0d8d351c47f7',
#    'before': 'b72850eadb970c392d891a2d2dea712f107517e3',
#    'commits': [{'sha': 'c32e587995def8b6b12489983bdd0d8d351c47f7',
#      'author': {'email': 'shaurya.src@gmail.com', 'name': 'Shaurya Choudhary'},
#      'message': 'Add test images',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shaurya-src/CovidInsight/commits/c32e587995def8b6b12489983bdd0d8d351c47f7'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697853',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 387882068,
#    'name': 'neschenbaum/neschenbaum.github.io',
#    'url': 'https://api.github.com/repos/neschenbaum/neschenbaum.github.io'},
#   'payload': {'push_id': 8461343783,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'dbe2772e6c1609a08f46e12f6c676e1b6cf26f8e',
#    'before': 'efad5bba60c1149ff09996c854514cd832f69d71',
#    'commits': [{'sha': 'fc601aedacc985930ee6ea9b783327c8635ff222',
#      'author': {'email': 'nicolas.eschenbaum@gmail.com',
#       'name': 'neschenbaum'},
#      'message': 'small update algo project and cv',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/neschenbaum/neschenbaum.github.io/commits/fc601aedacc985930ee6ea9b783327c8635ff222'},
#     {'sha': 'dbe2772e6c1609a08f46e12f6c676e1b6cf26f8e',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'GitHub Action'},
#      'message': 'small update algo project and cv [ci skip]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/neschenbaum/neschenbaum.github.io/commits/dbe2772e6c1609a08f46e12f6c676e1b6cf26f8e'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697879',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 368747752,
#    'name': 'unlimited-react-components/react-highlight',
#    'url': 'https://api.github.com/repos/unlimited-react-components/react-highlight'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/fork-ts-checker-webpack-plugin-6.4.2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A react component for highlighting JSX code.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z',
#   'org': {'id': 80552721,
#    'login': 'unlimited-react-components',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/unlimited-react-components',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80552721?'}},
#  {'id': '19030697816',
#   'type': 'PushEvent',
#   'actor': {'id': 26602940,
#    'login': '0xflotus',
#    'display_login': '0xflotus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/0xflotus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26602940?'},
#   'repo': {'id': 335254625,
#    'name': '0xflotus/github-page-monitoring',
#    'url': 'https://api.github.com/repos/0xflotus/github-page-monitoring'},
#   'payload': {'push_id': 8461343749,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '71aa0624a6d2f68784f0b09eba4ec6615253542b',
#    'before': '1914a910ad0edbd8729a1d0e14b7f91be84e7692',
#    'commits': [{'sha': 'e9fc93b8587bec5610a35e0d3726374fdb6aa3ea',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': ':pencil: Update summary in README [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/0xflotus/github-page-monitoring/commits/e9fc93b8587bec5610a35e0d3726374fdb6aa3ea'},
#     {'sha': '71aa0624a6d2f68784f0b09eba4ec6615253542b',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': ':card_file_box: Update status summary [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/0xflotus/github-page-monitoring/commits/71aa0624a6d2f68784f0b09eba4ec6615253542b'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697812',
#   'type': 'PushEvent',
#   'actor': {'id': 47844,
#    'login': 'kiang',
#    'display_login': 'kiang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kiang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47844?'},
#   'repo': {'id': 267529847,
#    'name': 'kiang/cit_water',
#    'url': 'https://api.github.com/repos/kiang/cit_water'},
#   'payload': {'push_id': 8461343761,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '6f10ae89708642063571da41cd4f90a0691c4164',
#    'before': '9312b79c6d19cd03bfdc02eac85d049688ef2f24',
#    'commits': [{'sha': '6f10ae89708642063571da41cd4f90a0691c4164',
#      'author': {'email': 'noreply@localhost', 'name': 'auto commit'},
#      'message': 'auto update @ 2021-11-24 18:21:01',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kiang/cit_water/commits/6f10ae89708642063571da41cd4f90a0691c4164'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'},
#  {'id': '19030697836',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 74924917,
#    'login': 'T-727',
#    'display_login': 'T-727',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/T-727',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74924917?'},
#   'repo': {'id': 431066594,
#    'name': 'T-727/MCPropertyEncyclopedia',
#    'url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia'},
#   'payload': {'action': 'closed',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/pulls/1',
#     'id': 787792987,
#     'node_id': 'PR_kwDOGbGN4s4u9MRb',
#     'html_url': 'https://github.com/T-727/MCPropertyEncyclopedia/pull/1',
#     'diff_url': 'https://github.com/T-727/MCPropertyEncyclopedia/pull/1.diff',
#     'patch_url': 'https://github.com/T-727/MCPropertyEncyclopedia/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/issues/1',
#     'number': 1,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Fix + added properties',
#     'user': {'login': 'T-727',
#      'id': 74924917,
#      'node_id': 'MDQ6VXNlcjc0OTI0OTE3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/74924917?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/T-727',
#      'html_url': 'https://github.com/T-727',
#      'followers_url': 'https://api.github.com/users/T-727/followers',
#      'following_url': 'https://api.github.com/users/T-727/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/T-727/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/T-727/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/T-727/subscriptions',
#      'organizations_url': 'https://api.github.com/users/T-727/orgs',
#      'repos_url': 'https://api.github.com/users/T-727/repos',
#      'events_url': 'https://api.github.com/users/T-727/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/T-727/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '- Changed "Grass Path" to "Dirt Path"\r\n- Added "Placable next to cactus" property\r\n- Added "Waterloggable" property',
#     'created_at': '2021-11-24T10:21:10Z',
#     'updated_at': '2021-11-24T10:21:26Z',
#     'closed_at': '2021-11-24T10:21:26Z',
#     'merged_at': None,
#     'merge_commit_sha': '1479d31cd8222d63508b7c21594b5b48ba682fba',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/statuses/c2a17c00b9152215647980747be0d063a5e4768f',
#     'head': {'label': 'T-727:T-727-patch-1',
#      'ref': 'T-727-patch-1',
#      'sha': 'c2a17c00b9152215647980747be0d063a5e4768f',
#      'user': {'login': 'T-727',
#       'id': 74924917,
#       'node_id': 'MDQ6VXNlcjc0OTI0OTE3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/74924917?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/T-727',
#       'html_url': 'https://github.com/T-727',
#       'followers_url': 'https://api.github.com/users/T-727/followers',
#       'following_url': 'https://api.github.com/users/T-727/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/T-727/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/T-727/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/T-727/subscriptions',
#       'organizations_url': 'https://api.github.com/users/T-727/orgs',
#       'repos_url': 'https://api.github.com/users/T-727/repos',
#       'events_url': 'https://api.github.com/users/T-727/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/T-727/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 431066594,
#       'node_id': 'R_kgDOGbGN4g',
#       'name': 'MCPropertyEncyclopedia',
#       'full_name': 'T-727/MCPropertyEncyclopedia',
#       'private': False,
#       'owner': {'login': 'T-727',
#        'id': 74924917,
#        'node_id': 'MDQ6VXNlcjc0OTI0OTE3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/74924917?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/T-727',
#        'html_url': 'https://github.com/T-727',
#        'followers_url': 'https://api.github.com/users/T-727/followers',
#        'following_url': 'https://api.github.com/users/T-727/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/T-727/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/T-727/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/T-727/subscriptions',
#        'organizations_url': 'https://api.github.com/users/T-727/orgs',
#        'repos_url': 'https://api.github.com/users/T-727/repos',
#        'events_url': 'https://api.github.com/users/T-727/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/T-727/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/T-727/MCPropertyEncyclopedia',
#       'description': 'A tool for viewing, filtering, and (eventually lol) sorting all blocks by their properties. ',
#       'fork': True,
#       'url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia',
#       'forks_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/forks',
#       'keys_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/teams',
#       'hooks_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/hooks',
#       'issue_events_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/events',
#       'assignees_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/tags',
#       'blobs_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/languages',
#       'stargazers_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/stargazers',
#       'contributors_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/contributors',
#       'subscribers_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/subscribers',
#       'subscription_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/subscription',
#       'commits_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/merges',
#       'archive_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/downloads',
#       'issues_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/T-727/MCPropertyEncyclopedia/deployments',
#       'created_at': '2021-11-23T11:02:35Z',
#       'updated_at': '2021-11-24T09:31:52Z',
#       'pushed_at': '2021-11-24T10:21:10Z',
#       'git_url': 'git://github.com/T-727/MCPropertyEncyclopedia.git',
#       'ssh_url': 'git@github.com:T-727/MCPropertyEncyclopedia.git',
#       'clone_url': 'https://github.com/T-727/MCPropertyEncyclopedia.git',
#       'svn_url': 'https://github.com/T-727/MCPropertyEncyclopedia',
#       'homepage': None,
#       'size': 564,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'T-727:main',
#      'ref': 'main',
#      'sha': '8c39e6f0e02964f7f2f0a73c838ce3d3294028ba',
#      'user': {'login': 'T-727',
#       'id': 74924917,
#       'node_id': 'MDQ6VXNlcjc0OTI0OTE3',
# ...
#      'subscriptions_url': 'https://api.github.com/users/xyzabcdefg/subscriptions',
#      'organizations_url': 'https://api.github.com/users/xyzabcdefg/orgs',
#      'repos_url': 'https://api.github.com/users/xyzabcdefg/repos',
#      'events_url': 'https://api.github.com/users/xyzabcdefg/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/xyzabcdefg/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2021-11-23T12:50:09Z',
#     'updated_at': '2021-11-24T10:21:26Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '646e27bf537446a8ce9f8406e96b55b92a37ef23',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/rolee15/PimsExporter/pulls/44/commits',
#     'review_comments_url': 'https://api.github.com/repos/rolee15/PimsExporter/pulls/44/comments',
#     'review_comment_url': 'https://api.github.com/repos/rolee15/PimsExporter/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/rolee15/PimsExporter/issues/44/comments',
#     'statuses_url': 'https://api.github.com/repos/rolee15/PimsExporter/statuses/4d63faa3c743fc75158caed1d8ee893dcf05c852',
#     'head': {'label': 'rolee15:zskondrai/cosignaturecosignerlist',
#      'ref': 'zskondrai/cosignaturecosignerlist',
#      'sha': '4d63faa3c743fc75158caed1d8ee893dcf05c852',
#      'user': {'login': 'rolee15',
#       'id': 14920305,
#       'node_id': 'MDQ6VXNlcjE0OTIwMzA1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/14920305?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rolee15',
#       'html_url': 'https://github.com/rolee15',
#       'followers_url': 'https://api.github.com/users/rolee15/followers',
#       'following_url': 'https://api.github.com/users/rolee15/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rolee15/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rolee15/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rolee15/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rolee15/orgs',
#       'repos_url': 'https://api.github.com/users/rolee15/repos',
#       'events_url': 'https://api.github.com/users/rolee15/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rolee15/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 417036264,
#       'node_id': 'R_kgDOGNt36A',
#       'name': 'PimsExporter',
#       'full_name': 'rolee15/PimsExporter',
#       'private': False,
#       'owner': {'login': 'rolee15',
#        'id': 14920305,
#        'node_id': 'MDQ6VXNlcjE0OTIwMzA1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/14920305?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rolee15',
#        'html_url': 'https://github.com/rolee15',
#        'followers_url': 'https://api.github.com/users/rolee15/followers',
#        'following_url': 'https://api.github.com/users/rolee15/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rolee15/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rolee15/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rolee15/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rolee15/orgs',
#        'repos_url': 'https://api.github.com/users/rolee15/repos',
#        'events_url': 'https://api.github.com/users/rolee15/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rolee15/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/rolee15/PimsExporter',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/rolee15/PimsExporter',
#       'forks_url': 'https://api.github.com/repos/rolee15/PimsExporter/forks',
#       'keys_url': 'https://api.github.com/repos/rolee15/PimsExporter/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rolee15/PimsExporter/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rolee15/PimsExporter/teams',
#       'hooks_url': 'https://api.github.com/repos/rolee15/PimsExporter/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rolee15/PimsExporter/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rolee15/PimsExporter/events',
#       'assignees_url': 'https://api.github.com/repos/rolee15/PimsExporter/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rolee15/PimsExporter/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rolee15/PimsExporter/tags',
#       'blobs_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rolee15/PimsExporter/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rolee15/PimsExporter/languages',
#       'stargazers_url': 'https://api.github.com/repos/rolee15/PimsExporter/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rolee15/PimsExporter/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rolee15/PimsExporter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rolee15/PimsExporter/subscription',
#       'commits_url': 'https://api.github.com/repos/rolee15/PimsExporter/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rolee15/PimsExporter/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rolee15/PimsExporter/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rolee15/PimsExporter/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rolee15/PimsExporter/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rolee15/PimsExporter/merges',
#       'archive_url': 'https://api.github.com/repos/rolee15/PimsExporter/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rolee15/PimsExporter/downloads',
#       'issues_url': 'https://api.github.com/repos/rolee15/PimsExporter/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rolee15/PimsExporter/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rolee15/PimsExporter/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rolee15/PimsExporter/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rolee15/PimsExporter/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rolee15/PimsExporter/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rolee15/PimsExporter/deployments',
#       'created_at': '2021-10-14T07:44:15Z',
#       'updated_at': '2021-11-22T15:27:04Z',
#       'pushed_at': '2021-11-24T09:30:37Z',
#       'git_url': 'git://github.com/rolee15/PimsExporter.git',
#       'ssh_url': 'git@github.com:rolee15/PimsExporter.git',
#       'clone_url': 'https://github.com/rolee15/PimsExporter.git',
#       'svn_url': 'https://github.com/rolee15/PimsExporter',
#       'homepage': None,
#       'size': 245,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 18,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 18,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'rolee15:main',
#      'ref': 'main',
#      'sha': '39e9b87aee975a4208318375ed86a235226a081a',
#      'user': {'login': 'rolee15',
#       'id': 14920305,
#       'node_id': 'MDQ6VXNlcjE0OTIwMzA1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/14920305?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rolee15',
#       'html_url': 'https://github.com/rolee15',
#       'followers_url': 'https://api.github.com/users/rolee15/followers',
#       'following_url': 'https://api.github.com/users/rolee15/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rolee15/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rolee15/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rolee15/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rolee15/orgs',
#       'repos_url': 'https://api.github.com/users/rolee15/repos',
#       'events_url': 'https://api.github.com/users/rolee15/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rolee15/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 417036264,
#       'node_id': 'R_kgDOGNt36A',
#       'name': 'PimsExporter',
#       'full_name': 'rolee15/PimsExporter',
#       'private': False,
#       'owner': {'login': 'rolee15',
#        'id': 14920305,
#        'node_id': 'MDQ6VXNlcjE0OTIwMzA1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/14920305?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rolee15',
#        'html_url': 'https://github.com/rolee15',
#        'followers_url': 'https://api.github.com/users/rolee15/followers',
#        'following_url': 'https://api.github.com/users/rolee15/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rolee15/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rolee15/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rolee15/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rolee15/orgs',
#        'repos_url': 'https://api.github.com/users/rolee15/repos',
#        'events_url': 'https://api.github.com/users/rolee15/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rolee15/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/rolee15/PimsExporter',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/rolee15/PimsExporter',
#       'forks_url': 'https://api.github.com/repos/rolee15/PimsExporter/forks',
#       'keys_url': 'https://api.github.com/repos/rolee15/PimsExporter/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rolee15/PimsExporter/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rolee15/PimsExporter/teams',
#       'hooks_url': 'https://api.github.com/repos/rolee15/PimsExporter/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rolee15/PimsExporter/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rolee15/PimsExporter/events',
#       'assignees_url': 'https://api.github.com/repos/rolee15/PimsExporter/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rolee15/PimsExporter/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rolee15/PimsExporter/tags',
#       'blobs_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rolee15/PimsExporter/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rolee15/PimsExporter/languages',
#       'stargazers_url': 'https://api.github.com/repos/rolee15/PimsExporter/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rolee15/PimsExporter/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rolee15/PimsExporter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rolee15/PimsExporter/subscription',
#       'commits_url': 'https://api.github.com/repos/rolee15/PimsExporter/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rolee15/PimsExporter/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rolee15/PimsExporter/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rolee15/PimsExporter/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rolee15/PimsExporter/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rolee15/PimsExporter/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rolee15/PimsExporter/merges',
#       'archive_url': 'https://api.github.com/repos/rolee15/PimsExporter/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rolee15/PimsExporter/downloads',
#       'issues_url': 'https://api.github.com/repos/rolee15/PimsExporter/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rolee15/PimsExporter/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rolee15/PimsExporter/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rolee15/PimsExporter/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rolee15/PimsExporter/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rolee15/PimsExporter/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rolee15/PimsExporter/deployments',
#       'created_at': '2021-10-14T07:44:15Z',
#       'updated_at': '2021-11-22T15:27:04Z',
#       'pushed_at': '2021-11-24T09:30:37Z',
#       'git_url': 'git://github.com/rolee15/PimsExporter.git',
#       'ssh_url': 'git@github.com:rolee15/PimsExporter.git',
#       'clone_url': 'https://github.com/rolee15/PimsExporter.git',
#       'svn_url': 'https://github.com/rolee15/PimsExporter',
#       'homepage': None,
#       'size': 245,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 18,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 18,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/rolee15/PimsExporter/pulls/44'},
#      'html': {'href': 'https://github.com/rolee15/PimsExporter/pull/44'},
#      'issue': {'href': 'https://api.github.com/repos/rolee15/PimsExporter/issues/44'},
#      'comments': {'href': 'https://api.github.com/repos/rolee15/PimsExporter/issues/44/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/rolee15/PimsExporter/pulls/44/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/rolee15/PimsExporter/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/rolee15/PimsExporter/pulls/44/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/rolee15/PimsExporter/statuses/4d63faa3c743fc75158caed1d8ee893dcf05c852'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-11-24T10:21:27Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   19030697896                      PushEvent
# 1   19030697911                      PushEvent
# 2   19030697927               PullRequestEvent
# 3   19030697917                      PushEvent
# 4   19030697915                      PushEvent
# 5   19030697887                      PushEvent
# 6   19030697932                     WatchEvent
# 7   19030697919                      PushEvent
# 8   19030697934                    CreateEvent
# 9   19030697907                    CreateEvent
# 10  19030697933                    CreateEvent
# 11  19030697906                      PushEvent
# 12  19030697886                     WatchEvent
# 13  19030697893                      PushEvent
# 14  19030697853                      PushEvent
# 15  19030697879                    CreateEvent
# 16  19030697816                      PushEvent
# 17  19030697812                      PushEvent
# 18  19030697836               PullRequestEvent
# 19  19030697808                    CreateEvent
# 20  19030697835  PullRequestReviewCommentEvent
# 21  19030697809                    CreateEvent
# 22  19030697827  PullRequestReviewCommentEvent
# 23  19030697824                    CreateEvent
# 24  19030697784         PullRequestReviewEvent
# 25  19030697760                      PushEvent
# 26  19030697805                    CreateEvent
# 27  19030697780                      PushEvent
# 28  19030697781         PullRequestReviewEvent
# 29  19030697787         PullRequestReviewEvent
#
#                                                 actor  \
# 0   {'id': 15614155, 'login': 'IgorBaratta', 'disp...
# 1   {'id': 69833978, 'login': 'mohmohaye707', 'dis...
# 2   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 3   {'id': 13050025, 'login': 'aladdin-add', 'disp...
# 4   {'id': 84066249, 'login': 'jaeseonNamgung', 'd...
# 5   {'id': 693300, 'login': 'labeneko', 'display_l...
# 6   {'id': 16855333, 'login': 'pedrorlmarques', 'd...
# 7   {'id': 92030018, 'login': 'v-rpatkur', 'displa...
# 8   {'id': 89453364, 'login': 'ViktorTB', 'display...
# 9   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 10  {'id': 61286605, 'login': 'AlexShkreba', 'disp...
# 11  {'id': 94030960, 'login': 'banifahlevi', 'disp...
# 12  {'id': 76036471, 'login': 'ffit8', 'display_lo...
# 13  {'id': 41169759, 'login': 'shaurya-src', 'disp...
# 14  {'id': 41898282, 'login': 'github-actions[bot]...
# 15  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 16  {'id': 26602940, 'login': '0xflotus', 'display...
# 17  {'id': 47844, 'login': 'kiang', 'display_login...
# 18  {'id': 74924917, 'login': 'T-727', 'display_lo...
# 19  {'id': 77669788, 'login': 'salrepepe', 'displa...
# 20  {'id': 14905380, 'login': 'fluiddot', 'display...
# 21  {'id': 60659566, 'login': 'weirdabyte', 'displ...
# 22  {'id': 5988959, 'login': 'arnaudlewis', 'displ...
# 23  {'id': 49100607, 'login': 'artemkoteluk', 'dis...
# 24  {'id': 5988959, 'login': 'arnaudlewis', 'displ...
# 25  {'id': 40338698, 'login': 'HannaChernihina', '...
# 26  {'id': 84447693, 'login': 'Abhishek-1301', 'di...
# 27  {'id': 41898282, 'login': 'github-actions[bot]...
# 28  {'id': 14905380, 'login': 'fluiddot', 'display...
# 29  {'id': 14920305, 'login': 'rolee15', 'display_...
#
#                                                  repo  \
# 0   {'id': 128215037, 'name': 'FEniCS/ffcx', 'url'...
# 1   {'id': 430998830, 'name': 'mohmohaye707/Crud_r...
# 2   {'id': 147852516, 'name': 'nwtgck/fakelish-npm...
# 3   {'id': 416723766, 'name': 'weiran-zsd/talks', ...
# 4   {'id': 398953505, 'name': 'jaeseonNamgung/Stud...
# 5   {'id': 418538630, 'name': 'labeneko/keihin0078...
# 6   {'id': 352759446, 'name': 'vinsguru/rsocket-co...
# 7   {'id': 378043407, 'name': 'zyxiaoyuer/msteams-...
# 8   {'id': 426579718, 'name': 'ViktorTB/Mini-eksam...
# 9   {'id': 147852516, 'name': 'nwtgck/fakelish-npm...
# 10  {'id': 426592187, 'name': 'AlexShkreba/mobile-...
# 11  {'id': 431019726, 'name': 'banifahlevi/banifah...
# 12  {'id': 405838857, 'name': 'qishanzhiruan/basem...
# 13  {'id': 414986829, 'name': 'shaurya-src/CovidIn...
# 14  {'id': 387882068, 'name': 'neschenbaum/neschen...
# 15  {'id': 368747752, 'name': 'unlimited-react-com...
# 16  {'id': 335254625, 'name': '0xflotus/github-pag...
# 17  {'id': 267529847, 'name': 'kiang/cit_water', '...
# 18  {'id': 431066594, 'name': 'T-727/MCPropertyEnc...
# 19  {'id': 431438183, 'name': 'salrepepe/netex-bui...
# 20  {'id': 80862584, 'name': 'WordPress/gutenberg'...
# 21  {'id': 431438184, 'name': 'weirdabyte/kurs-git...
# 22  {'id': 239547460, 'name': 'prismicio/slice-mac...
# 23  {'id': 431436216, 'name': 'artemkoteluk/exampl...
# 24  {'id': 239547460, 'name': 'prismicio/slice-mac...
# 25  {'id': 371476781, 'name': 'HannaChernihina/tas...
# 26  {'id': 431417579, 'name': 'Abhishek-1301/Sourc...
# 27  {'id': 404304956, 'name': 'Petit-Abba/backup_s...
# 28  {'id': 80862584, 'name': 'WordPress/gutenberg'...
# 29  {'id': 417036264, 'name': 'rolee15/PimsExporte...
#
#                                               payload  public  \
# 0   {'push_id': 8461343794, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 8461343824, 'size': 1, 'distinct_s...    True
# 2   {'action': 'opened', 'number': 106, 'pull_requ...    True
# 3   {'push_id': 8461343812, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 8461343818, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 8461343804, 'size': 1, 'distinct_s...    True
# 6                               {'action': 'started'}    True
# 7   {'push_id': 8461343789, 'size': 1, 'distinct_s...    True
# 8   {'ref': 'Lærer', 'ref_type': 'branch', 'master...    True
# 9   {'ref': 'dependabot/npm_and_yarn/types/node-16...    True
# 10  {'ref': 'tests', 'ref_type': 'branch', 'master...    True
# 11  {'push_id': 8461343827, 'size': 1, 'distinct_s...    True
# 12                              {'action': 'started'}    True
# 13  {'push_id': 8461343793, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 8461343783, 'size': 2, 'distinct_s...    True
# 15  {'ref': 'dependabot/npm_and_yarn/fork-ts-check...    True
# 16  {'push_id': 8461343749, 'size': 2, 'distinct_s...    True
# 17  {'push_id': 8461343761, 'size': 1, 'distinct_s...    True
# 18  {'action': 'closed', 'number': 1, 'pull_reques...    True
# 19  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 20  {'action': 'created', 'comment': {'url': 'http...    True
# 21  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 22  {'action': 'created', 'comment': {'url': 'http...    True
# 23  {'ref': 'example', 'ref_type': 'branch', 'mast...    True
# 24  {'action': 'created', 'review': {'id': 8146900...    True
# 25  {'push_id': 8461343737, 'size': 1, 'distinct_s...    True
# 26  {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 27  {'push_id': 8461343746, 'size': 1, 'distinct_s...    True
# 28  {'action': 'created', 'review': {'id': 8146900...    True
# 29  {'action': 'created', 'review': {'id': 8146900...    True
#
#               created_at                                                org
# 0   2021-11-24T10:21:27Z  {'id': 3868708, 'login': 'FEniCS', 'gravatar_i...
# 1   2021-11-24T10:21:27Z                                                NaN
# 2   2021-11-24T10:21:27Z                                                NaN
# 3   2021-11-24T10:21:27Z  {'id': 74645970, 'login': 'weiran-zsd', 'grava...
# 4   2021-11-24T10:21:27Z                                                NaN
# 5   2021-11-24T10:21:27Z                                                NaN
# 6   2021-11-24T10:21:27Z                                                NaN
# 7   2021-11-24T10:21:27Z                                                NaN
# 8   2021-11-24T10:21:27Z                                                NaN
# 9   2021-11-24T10:21:27Z                                                NaN
# 10  2021-11-24T10:21:27Z                                                NaN
# 11  2021-11-24T10:21:27Z                                                NaN
# 12  2021-11-24T10:21:27Z                                                NaN
# 13  2021-11-24T10:21:27Z                                                NaN
# 14  2021-11-24T10:21:27Z                                                NaN
# 15  2021-11-24T10:21:27Z  {'id': 80552721, 'login': 'unlimited-react-com...
# 16  2021-11-24T10:21:27Z                                                NaN
# 17  2021-11-24T10:21:27Z                                                NaN
# 18  2021-11-24T10:21:27Z                                                NaN
# 19  2021-11-24T10:21:27Z                                                NaN
# 20  2021-11-24T10:21:26Z  {'id': 276006, 'login': 'WordPress', 'gravatar...
# 21  2021-11-24T10:21:27Z                                                NaN
# 22  2021-11-24T10:21:26Z  {'id': 4621061, 'login': 'prismicio', 'gravata...
# 23  2021-11-24T10:21:27Z                                                NaN
# 24  2021-11-24T10:21:27Z  {'id': 4621061, 'login': 'prismicio', 'gravata...
# 25  2021-11-24T10:21:27Z                                                NaN
# 26  2021-11-24T10:21:27Z                                                NaN
# 27  2021-11-24T10:21:27Z                                                NaN
# 28  2021-11-24T10:21:27Z  {'id': 276006, 'login': 'WordPress', 'gravatar...
# 29  2021-11-24T10:21:27Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id              type  public            created_at  actor.id  \
# 0   19027907810         PushEvent    True  2021-11-24T07:15:56Z  69902583
# 1   19027907832       CreateEvent    True  2021-11-24T07:15:56Z  75158103
# 2   19027907838       CreateEvent    True  2021-11-24T07:15:56Z  71354125
# 3   19027907799         PushEvent    True  2021-11-24T07:15:56Z  93641609
# 4   19027907796         PushEvent    True  2021-11-24T07:15:56Z  45362986
# 5   19027907769         PushEvent    True  2021-11-24T07:15:56Z  50871412
# 6   19027907797         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 7   19027907792         PushEvent    True  2021-11-24T07:15:56Z  52286662
# 8   19027907747         PushEvent    True  2021-11-24T07:15:56Z   9650581
# 9   19027907773  PullRequestEvent    True  2021-11-24T07:15:56Z  39814207
# 10  19027907731         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 11  19027907732         PushEvent    True  2021-11-24T07:15:56Z  24356597
# 12  19027907759         PushEvent    True  2021-11-24T07:15:56Z  82928831
# 13  19027907714  PullRequestEvent    True  2021-11-24T07:15:56Z  49859594
# 14  19027907734       CreateEvent    True  2021-11-24T07:15:56Z  80814896
# 15  19027907697         PushEvent    True  2021-11-24T07:15:56Z  59991511
# 16  19027907692         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 17  19027907712        WatchEvent    True  2021-11-24T07:15:56Z  40334071
# 18  19027907693         PushEvent    True  2021-11-24T07:15:56Z  22478978
# 19  19027907704         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 20  19027907680         PushEvent    True  2021-11-24T07:15:56Z  69158844
# 21  19027907672       CreateEvent    True  2021-11-24T07:15:56Z   6956310
# 22  19027907685         PushEvent    True  2021-11-24T07:15:56Z  90423959
# 23  19027907661         ForkEvent    True  2021-11-24T07:15:56Z  13044753
# 24  19027907664         PushEvent    True  2021-11-24T07:15:56Z  91318945
# 25  19027907674         PushEvent    True  2021-11-24T07:15:56Z  85677360
# 26  19027907670        WatchEvent    True  2021-11-24T07:15:56Z  89684029
# 27  19027907658         PushEvent    True  2021-11-24T07:15:55Z  41898282
# 28  19027907642        WatchEvent    True  2021-11-24T07:15:55Z     63482
# 29  19027907641  PullRequestEvent    True  2021-11-24T07:15:55Z   9650581
#
#                       actor.login       actor.display_login actor.gravatar_id  \
# 0                      SG-GIT-HUB                SG-GIT-HUB
# 1                        chen8908                  chen8908
# 2   aws-connector-for-github[bot]  aws-connector-for-github
# 3                   patrick-hoell             patrick-hoell
# 4                        joashdev                  joashdev
# 5                     jerryIsHere               jerryIsHere
# 6             github-actions[bot]            github-actions
# 7                       karata-sc                 karata-sc
# 8                        jiyuujin                  jiyuujin
# 9                       pull[bot]                      pull
# 10            github-actions[bot]            github-actions
# 11                  foramgandhi12             foramgandhi12
# 12                         imjoud                    imjoud
# 13                    Speedwag00n               Speedwag00n
# 14                      TaeYunAhn                 TaeYunAhn
# 15                         w-endo                    w-endo
# 16            github-actions[bot]            github-actions
# 17                    alicanertop               alicanertop
# 18                     LastSprint                LastSprint
# 19            github-actions[bot]            github-actions
# 20                   project20911              project20911
# 21                      jimmyzhen                 jimmyzhen
# 22                      pringle97                 pringle97
# 23                      menghaniv                 menghaniv
# 24                  PablioKonst88             PablioKonst88
# 25                     shuming-yu                shuming-yu
# 26                       Phongdho                  Phongdho
# 27            github-actions[bot]            github-actions
# 28                      defstream                 defstream
# 29                       jiyuujin                  jiyuujin
#
#                                             actor.url  \
# 0             https://api.github.com/users/SG-GIT-HUB
# 1               https://api.github.com/users/chen8908
# 2   https://api.github.com/users/aws-connector-for...
# 3          https://api.github.com/users/patrick-hoell
# 4               https://api.github.com/users/joashdev
# 5            https://api.github.com/users/jerryIsHere
# 6    https://api.github.com/users/github-actions[bot]
# 7              https://api.github.com/users/karata-sc
# 8               https://api.github.com/users/jiyuujin
# 9              https://api.github.com/users/pull[bot]
# 10   https://api.github.com/users/github-actions[bot]
# 11         https://api.github.com/users/foramgandhi12
# 12                https://api.github.com/users/imjoud
# 13           https://api.github.com/users/Speedwag00n
# 14             https://api.github.com/users/TaeYunAhn
# 15                https://api.github.com/users/w-endo
# 16   https://api.github.com/users/github-actions[bot]
# 17           https://api.github.com/users/alicanertop
# 18            https://api.github.com/users/LastSprint
# 19   https://api.github.com/users/github-actions[bot]
# 20          https://api.github.com/users/project20911
# 21             https://api.github.com/users/jimmyzhen
# 22             https://api.github.com/users/pringle97
# 23             https://api.github.com/users/menghaniv
# 24         https://api.github.com/users/PablioKonst88
# 25            https://api.github.com/users/shuming-yu
# 26              https://api.github.com/users/Phongdho
# 27   https://api.github.com/users/github-actions[bot]
# 28             https://api.github.com/users/defstream
# 29              https://api.github.com/users/jiyuujin
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/69902583?  ...
# 1   https://avatars.githubusercontent.com/u/75158103?  ...
# 2   https://avatars.githubusercontent.com/u/71354125?  ...
# 3   https://avatars.githubusercontent.com/u/93641609?  ...
# 4   https://avatars.githubusercontent.com/u/45362986?  ...
# 5   https://avatars.githubusercontent.com/u/50871412?  ...
# 6   https://avatars.githubusercontent.com/u/41898282?  ...
# 7   https://avatars.githubusercontent.com/u/52286662?  ...
# 8    https://avatars.githubusercontent.com/u/9650581?  ...
# 9   https://avatars.githubusercontent.com/u/39814207?  ...
# 10  https://avatars.githubusercontent.com/u/41898282?  ...
# 11  https://avatars.githubusercontent.com/u/24356597?  ...
# 12  https://avatars.githubusercontent.com/u/82928831?  ...
# 13  https://avatars.githubusercontent.com/u/49859594?  ...
# 14  https://avatars.githubusercontent.com/u/80814896?  ...
# 15  https://avatars.githubusercontent.com/u/59991511?  ...
# 16  https://avatars.githubusercontent.com/u/41898282?  ...
# 17  https://avatars.githubusercontent.com/u/40334071?  ...
# 18  https://avatars.githubusercontent.com/u/22478978?  ...
# 19  https://avatars.githubusercontent.com/u/41898282?  ...
# 20  https://avatars.githubusercontent.com/u/69158844?  ...
# 21   https://avatars.githubusercontent.com/u/6956310?  ...
# 22  https://avatars.githubusercontent.com/u/90423959?  ...
# 23  https://avatars.githubusercontent.com/u/13044753?  ...
# 24  https://avatars.githubusercontent.com/u/91318945?  ...
# 25  https://avatars.githubusercontent.com/u/85677360?  ...
# 26  https://avatars.githubusercontent.com/u/89684029?  ...
# 27  https://avatars.githubusercontent.com/u/41898282?  ...
# 28     https://avatars.githubusercontent.com/u/63482?  ...
# 29   https://avatars.githubusercontent.com/u/9650581?  ...
#
#     payload.forkee.license payload.forkee.allow_forking  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# 5                      NaN                          NaN
# 6                      NaN                          NaN
# 7                      NaN                          NaN
# 8                      NaN                          NaN
# 9                      NaN                          NaN
# 10                     NaN                          NaN
# 11                     NaN                          NaN
# 12                     NaN                          NaN
# 13                     NaN                          NaN
# 14                     NaN                          NaN
# 15                     NaN                          NaN
# 16                     NaN                          NaN
# 17                     NaN                          NaN
# 18                     NaN                          NaN
# 19                     NaN                          NaN
# 20                     NaN                          NaN
# 21                     NaN                          NaN
# 22                     NaN                          NaN
# 23                     NaN                         True
# 24                     NaN                          NaN
# 25                     NaN                          NaN
# 26                     NaN                          NaN
# 27                     NaN                          NaN
# 28                     NaN                          NaN
# 29                     NaN                          NaN
#
#    payload.forkee.is_template  payload.forkee.topics  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# 5                         NaN                    NaN
# 6                         NaN                    NaN
# 7                         NaN                    NaN
# 8                         NaN                    NaN
# 9                         NaN                    NaN
# 10                        NaN                    NaN
# 11                        NaN                    NaN
# 12                        NaN                    NaN
# 13                        NaN                    NaN
# 14                        NaN                    NaN
# 15                        NaN                    NaN
# 16                        NaN                    NaN
# 17                        NaN                    NaN
# 18                        NaN                    NaN
# 19                        NaN                    NaN
# 20                        NaN                    NaN
# 21                        NaN                    NaN
# 22                        NaN                    NaN
# 23                      False                     []
# 24                        NaN                    NaN
# 25                        NaN                    NaN
# 26                        NaN                    NaN
# 27                        NaN                    NaN
# 28                        NaN                    NaN
# 29                        NaN                    NaN
#
#     payload.forkee.visibility  payload.forkee.forks  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
# 5                         NaN                   NaN
# 6                         NaN                   NaN
# 7                         NaN                   NaN
# 8                         NaN                   NaN
# 9                         NaN                   NaN
# 10                        NaN                   NaN
# 11                        NaN                   NaN
# 12                        NaN                   NaN
# 13                        NaN                   NaN
# 14                        NaN                   NaN
# 15                        NaN                   NaN
# 16                        NaN                   NaN
# 17                        NaN                   NaN
# 18                        NaN                   NaN
# 19                        NaN                   NaN
# 20                        NaN                   NaN
# 21                        NaN                   NaN
# 22                        NaN                   NaN
# 23                     public                   0.0
# 24                        NaN                   NaN
# 25                        NaN                   NaN
# 26                        NaN                   NaN
# 27                        NaN                   NaN
# 28                        NaN                   NaN
# 29                        NaN                   NaN
#
#    payload.forkee.open_issues payload.forkee.watchers  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# 7                         NaN                     NaN
# 8                         NaN                     NaN
# 9                         NaN                     NaN
# 10                        NaN                     NaN
# 11                        NaN                     NaN
# 12                        NaN                     NaN
# 13                        NaN                     NaN
# 14                        NaN                     NaN
# 15                        NaN                     NaN
# 16                        NaN                     NaN
# 17                        NaN                     NaN
# 18                        NaN                     NaN
# 19                        NaN                     NaN
# 20                        NaN                     NaN
# 21                        NaN                     NaN
# 22                        NaN                     NaN
# 23                        0.0                     0.0
# 24                        NaN                     NaN
# 25                        NaN                     NaN
# 26                        NaN                     NaN
# 27                        NaN                     NaN
# 28                        NaN                     NaN
# 29                        NaN                     NaN
#
#    payload.forkee.default_branch payload.forkee.public
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
# 6                            NaN                   NaN
# 7                            NaN                   NaN
# 8                            NaN                   NaN
# 9                            NaN                   NaN
# 10                           NaN                   NaN
# 11                           NaN                   NaN
# 12                           NaN                   NaN
# 13                           NaN                   NaN
# 14                           NaN                   NaN
# 15                           NaN                   NaN
# 16                           NaN                   NaN
# 17                           NaN                   NaN
# 18                           NaN                   NaN
# 19                           NaN                   NaN
# 20                           NaN                   NaN
# 21                           NaN                   NaN
# 22                           NaN                   NaN
# 23                          main                  True
# 24                           NaN                   NaN
# 25                           NaN                   NaN
# 26                           NaN                   NaN
# 27                           NaN                   NaN
# 28                           NaN                   NaN
# 29                           NaN                   NaN
#
# [30 rows x 444 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'timestamp': 1637750063,
#  'iss_position': {'latitude': '38.1947', 'longitude': '86.6616'},
#  'message': 'success'}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1637739535,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 536, 'risetime': 1637766652},
#   {'duration': 645, 'risetime': 1637772367},
#   {'duration': 660, 'risetime': 1637778159},
#   {'duration': 654, 'risetime': 1637783966},
#   {'duration': 593, 'risetime': 1637789779}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1637772367)
# Out:
# datetime.datetime(2021, 11, 24, 17, 46, 7)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gh/s8b9pd096y13z1bxsq63d0x40000gn/T/ipykernel_26336/494424325.py in <module>
#      10
#      11 headers = {
# ---> 12     'x-rapidapi-key': x_rapidapi_key,
#      13     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      14     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1637739535, 'latitude': 52.53370520371973, 'longitude': 13.453475292072312, 'passes': 5}, 'response': [{'duration': 536, 'risetime': 1637766652}, {'duration': 645, 'risetime': 1637772367}, {'duration': 660, 'risetime': 1637778159}, {'duration': 654, 'risetime': 1637783966}, {'duration': 593, 'risetime': 1637789779}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %%
results['data']
# Out:
# [{'app_temp': 25.4,
#   'aqi': 68,
#   'city_name': 'Zarzalejo',
#   'clouds': 75,
#   'country_code': 'ES',
#   'datetime': '2021-06-15:08',
#   'dewpt': 12.4,
#   'dhi': 92.52,
#   'dni': 808.24,
#   'elev_angle': 34.18,
#   'ghi': 540.97,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2021-06-15 08:00',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 945.1,
#   'rh': 44,
#   'slp': 1018.9,
#   'snow': 0,
#   'solar_rad': 378.2,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:44',
#   'sunset': '19:48',
#   'temp': 25.6,
#   'timezone': 'Europe/Madrid',
#   'ts': 1623744000,
#   'uv': 5.89272,
#   'vis': 5,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 44,
#   'wind_spd': 1}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...
